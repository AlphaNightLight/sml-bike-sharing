# %% [markdown]
# # <span style='color:#ff5f27'> Initialization </span>

# %% [markdown]
# ### Hopsworks Settings

# %%
import sys
from pathlib import Path
import os

def is_google_colab() -> bool:
    if "google.colab" in str(get_ipython()):
        return True
    return False

def clone_repository() -> None:
    # !git clone https://github.com/featurestorebook/mlfs-book.git
    # %cd mlfs-book

def install_dependencies() -> None:
    # !pip install --upgrade uv
    # !uv pip install --all-extras --system --requirement pyproject.toml

if is_google_colab():
    clone_repository()
    install_dependencies()
    root_dir = str(Path().absolute())
    print("Google Colab environment")
else:
    root_dir = Path().absolute()
    # Strip ~/notebooks/ccfraud from PYTHON_PATH if notebook started in one of these subdirectories
    if root_dir.parts[-1:] == ('airquality',):
        root_dir = Path(*root_dir.parts[:-1])
    if root_dir.parts[-1:] == ('notebooks',):
        root_dir = Path(*root_dir.parts[:-1])
    root_dir = str(root_dir) 
    print("Local environment")

# Add the root directory to the `PYTHONPATH` to use the `recsys` Python module from the notebook.
if root_dir not in sys.path:
    sys.path.append(root_dir)
print(f"Added the following directory to the PYTHONPATH: {root_dir}")
    
# Set the environment variables from the file <root_dir>/.env
from mlfs import config
if os.path.exists(f"{root_dir}/.env"):
    settings = config.HopsworksSettings(_env_file=f"{root_dir}/.env")
# Out:
# Local environment
# Added the following directory to the PYTHONPATH: c:\Users\nives\AllFolders\SML\sml-bike-sharing
# HopsworksSettings initialized!

# %% [markdown]
# ### Imports

# %%
from datetime import date, datetime, timedelta
import pandas as pd
import matplotlib.pyplot as plt
from xgboost import XGBRegressor
from xgboost import plot_importance
from sklearn.metrics import mean_squared_error, r2_score
import hopsworks
from mlfs import util
import json

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # <span style='color:#ff5f27'> Retrieve Data </span>

# %% [markdown]
# ### Retrieve Metadata

# %%
# Check if HOPSWORKS_API_KEY env variable is set or if it is set in ~/.env
if settings.HOPSWORKS_API_KEY is not None:
    api_key = settings.HOPSWORKS_API_KEY.get_secret_value()
    os.environ['HOPSWORKS_API_KEY'] = api_key
project = hopsworks.login()
fs = project.get_feature_store() 

secrets = hopsworks.get_secrets_api()
location_str = secrets.get_secret("BIKES_LOCATION_JSON").value
location = json.loads(location_str)

country=location['country']
city=location['city']
latitude=location['latitude']
longitude=location['longitude']
today = date.today()
yesterday = today - timedelta(days=1)

print(f"City: {city}")
print(f"Contry: {country}")
print(f"Latitude: {latitude}")
print(f"Longitude: {longitude}")
print(f"Day: {today}")
# Out:
# 2026-01-05 19:18:06,256 INFO: Closing external client and cleaning up certificates.
# 2026-01-05 19:18:06,259 INFO: Connection closed.
# 2026-01-05 19:18:06,261 INFO: Initializing external client
# 2026-01-05 19:18:06,261 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2026-01-05 19:18:07,712 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1279175
# City: Trento
# Contry: Italy
# Latitude: 46.07
# Longitude: 11.12
# Day: 2026-01-05

# %% [markdown]
# ### Connect to Feature Groups

# %%
bikes_fg = fs.get_feature_group(
    name='bikes_trento',
    version=1,
)
weather_fg = fs.get_feature_group(
    name='weather_trento',
    version=1,
)

# %% [markdown]
# ### Create Feature Views

# %%
selected_features = bikes_fg.select(
    ['id', 'bikes', 'date']
).join(weather_fg.select_features(), on=['city'])
# Out:
# 2026-01-05 19:19:52,116 INFO: Using ['weather_code', 'apparent_temperature_mean', 'daylight_duration', 'precipitation_sum', 'wind_speed_10m_max'] from feature group `weather_trento` as features for the query. To include primary key and event time use `select_all`.

# %%
feature_view = fs.get_or_create_feature_view(
    name='bikes_fv',
    description="Features selected for bike predictions.",
    version=1,
    labels=['bikes'],
    query=selected_features,
)

# %%
feature_view = fs.get_feature_view(name="bikes_fv", version=1)
feature_view.schema
# Out:
# [Training Dataset Feature('id', 'string', 0, False, id, 1911123, None),
#  Training Dataset Feature('bikes', 'int', 1, True, bikes, 1911123, None),
#  Training Dataset Feature('date', 'timestamp', 2, False, date, 1911123, None),
#  Training Dataset Feature('weather_code', 'int', 3, False, weather_code, 1908081, None),
#  Training Dataset Feature('apparent_temperature_mean', 'float', 4, False, apparent_temperature_mean, 1908081, None),
#  Training Dataset Feature('daylight_duration', 'float', 5, False, daylight_duration, 1908081, None),
#  Training Dataset Feature('precipitation_sum', 'float', 6, False, precipitation_sum, 1908081, None),
#  Training Dataset Feature('wind_speed_10m_max', 'float', 7, False, wind_speed_10m_max, 1908081, None)]

# %% [markdown]
# # <span style='color:#ff5f27'> Create Train/Test Datasets </span>

# %%
start_date_test_data = "2025-09-01"
# Convert string to datetime object
test_start = datetime.strptime(start_date_test_data, "%Y-%m-%d")

# %%
# get_data = feature_view.get_batch_data()

# %%
X_train, X_test, y_train, y_test = feature_view.train_test_split(
    test_start=test_start
)
# Out:
# 2026-01-05 19:33:42,202 ERROR: Binder Error: Referenced column "{'name': 'date', 'type': 'timestamp'}" not found in FROM clause!
# Candidate bindings: "read_parquet.date"
# LINE 1: ...dictor_fl.weather_trento_1" as (select "{'name': 'date', 'type': 'timestamp'}"...
#                                                   ^. Detail: Python exception: Traceback (most recent call last):
#   File "/usr/src/app/src/server.py", line 142, in wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/src/app/src/server.py", line 166, in wrapper
#     result = func(instance, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/src/app/src/server.py", line 196, in do_get
#     return self._read_query(context, path, command)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/src/app/src/server.py", line 123, in wrapper
#     return func(instance, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/src/app/src/server.py", line 131, in wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/src/app/src/server.py", line 227, in _read_query
#     result_batches = self.hudi_query_engine.read_query(query_obj)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/src/app/src/hudi_query_engine.py", line 75, in read_query
#     with duckdb.connect(
#   File "/usr/src/app/src/hudi_query_engine.py", line 90, in read_query
#     self._register_featuregroups(
#   File "/usr/src/app/src/hudi_query_engine.py", line 112, in _register_featuregroups
#     self._register_hudi_featuregroups(hudi_featuregroups_paths, featuregroup_features, duckdb_con)
#   File "/usr/src/app/src/hudi_query_engine.py", line 126, in _register_hudi_featuregroups
#     duckdb_con.sql(query)
# duckdb.duckdb.BinderException: Binder Error: Referenced column "{'name': 'date', 'type': 'timestamp'}" not found in FROM clause!
# Candidate bindings: "read_parquet.date"
# LINE 1: ...dictor_fl.weather_trento_1" as (select "{'name': 'date', 'type': 'timestamp'}"...
#                                                   ^
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "pyarrow/_flight.pyx", line 2255, in pyarrow._flight._do_get
#   File "/usr/src/app/src/server.py", line 145, in wrapper
#     raise FlyingDuckException(str(e)) from e
# utils.exceptions.FlyingDuckException: Binder Error: Referenced column "{'name': 'date', 'type': 'timestamp'}" not found in FROM clause!
# Candidate bindings: "read_parquet.date"
# LINE 1: ...dictor_fl.weather_trento_1" as (select "{'name': 'date', 'type': 'timestamp'}"...
#                                                   ^
# . gRPC client debug context: UNKNOWN:Error received from peer ipv4:51.79.26.27:5005 {grpc_message:"Binder Error: Referenced column \"{\'name\': \'date\', \'type\': \'timestamp\'}\" not found in FROM clause!\nCandidate bindings: \"read_parquet.date\"\nLINE 1: ...dictor_fl.weather_trento_1\" as (select \"{\'name\': \'date\', \'type\': \'timestamp\'}\"...\n                                                  ^. Detail: Python exception: Traceback (most recent call last):\n  File \"/usr/src/app/src/server.py\", line 142, in wrapper\n    result = func(*args, **kwargs)\n             ^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/src/app/src/server.py\", line 166, in wrapper\n    result = func(instance, *args, **kwargs)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/src/app/src/server.py\", line 196, in do_get\n    return self._read_query(context, path, command)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/src/app/src/server.py\", line 123, in wrapper\n    return func(instance, *args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/src/app/src/server.py\", line 131, in wrapper\n    result = func(*args, **kwargs)\n             ^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/src/app/src/server.py\", line 227, in _read_query\n    result_batches = self.hudi_query_engine.read_query(query_obj)\n                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/src/app/src/hudi_query_engine.py\", line 75, in read_query\n    with duckdb.connect(\n  File \"/usr/src/app/src/hudi_query_engine.py\", line 90, in read_query\n    self._register_featuregroups(\n  File \"/usr/src/app/src/hudi_query_engine.py\", line 112, in _register_featuregroups\n    self._register_hudi_featuregroups(hudi_featuregroups_paths, featuregroup_features, duckdb_con)\n  File \"/usr/src/app/src/hudi_query_engine.py\", line 126, in _register_hudi_featuregroups\n    duckdb_con.sql(query)\nduckdb.duckdb.BinderException: Binder Error: Referenced column \"{\'name\': \'date\', \'type\': \'timestamp\'}\" not found in FROM clause!\nCandidate bindings: \"read_parquet.date\"\nLINE 1: ...dictor_fl.weather_trento_1\" as (select \"{\'name\': \'date\', \'type\': \'timestamp\'}\"...\n                                                  ^\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"pyarrow/_flight.pyx\", line 2255, in pyarrow._flight._do_get\n  File \"/usr/src/app/src/server.py\", line 145, in wrapper\n    raise FlyingDuckException(str(e)) from e\nutils.exceptions.FlyingDuckException: Binder Error: Referenced column \"{\'name\': \'date\', \'type\': \'timestamp\'}\" not found in FROM clause!\nCandidate bindings: \"read_parquet.date\"\nLINE 1: ...dictor_fl.weather_trento_1\" as (select \"{\'name\': \'date\', \'type\': \'timestamp\'}\"...\n                                                  ^\n", grpc_status:2, created_time:"2026-01-05T18:33:42.182208+00:00"}. Client context: IOError: Server never sent a data message. Detail: Internal
# Traceback (most recent call last):
#   File "c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\hsfs\core\arrow_flight_client.py", line 418, in afs_error_handler_wrapper
#     return func(instance, *args, **kw)
#   File "c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\hsfs\core\arrow_flight_client.py", line 487, in read_query
#     return self._get_dataset(
#   File "c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\retrying.py", line 55, in wrapped_f
#     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#   File "c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\retrying.py", line 279, in call
#     return attempt.get(self._wrap_exception)
#   File "c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\retrying.py", line 326, in get
#     raise exc.with_traceback(tb)
#   File "c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\retrying.py", line 273, in call
#     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#   File "c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\hsfs\core\arrow_flight_client.py", line 473, in _get_dataset
#     reader = self._connection.do_get(info.endpoints[0].ticket, options)
#   File "pyarrow/_flight.pyx", line 1745, in pyarrow._flight.FlightClient.do_get
#   File "pyarrow/_flight.pyx", line 58, in pyarrow._flight.check_flight_status
# pyarrow._flight.FlightServerError: Binder Error: Referenced column "{'name': 'date', 'type': 'timestamp'}" not found in FROM clause!
# Candidate bindings: "read_parquet.date"
# LINE 1: ...dictor_fl.weather_trento_1" as (select "{'name': 'date', 'type': 'timestamp'}"...
#                                                   ^. Detail: Python exception: Traceback (most recent call last):
#   File "/usr/src/app/src/server.py", line 142, in wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/src/app/src/server.py", line 166, in wrapper
#     result = func(instance, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/src/app/src/server.py", line 196, in do_get
#     return self._read_query(context, path, command)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/src/app/src/server.py", line 123, in wrapper
#     return func(instance, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/src/app/src/server.py", line 131, in wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/src/app/src/server.py", line 227, in _read_query
#     result_batches = self.hudi_query_engine.read_query(query_obj)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/src/app/src/hudi_query_engine.py", line 75, in read_query
#     with duckdb.connect(
#   File "/usr/src/app/src/hudi_query_engine.py", line 90, in read_query
#     self._register_featuregroups(
#   File "/usr/src/app/src/hudi_query_engine.py", line 112, in _register_featuregroups
#     self._register_hudi_featuregroups(hudi_featuregroups_paths, featuregroup_features, duckdb_con)
#   File "/usr/src/app/src/hudi_query_engine.py", line 126, in _register_hudi_featuregroups
#     duckdb_con.sql(query)
# duckdb.duckdb.BinderException: Binder Error: Referenced column "{'name': 'date', 'type': 'timestamp'}" not found in FROM clause!
# Candidate bindings: "read_parquet.date"
# LINE 1: ...dictor_fl.weather_trento_1" as (select "{'name': 'date', 'type': 'timestamp'}"...
#                                                   ^
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "pyarrow/_flight.pyx", line 2255, in pyarrow._flight._do_get
#   File "/usr/src/app/src/server.py", line 145, in wrapper
#     raise FlyingDuckException(str(e)) from e
# utils.exceptions.FlyingDuckException: Binder Error: Referenced column "{'name': 'date', 'type': 'timestamp'}" not found in FROM clause!
# Candidate bindings: "read_parquet.date"
# LINE 1: ...dictor_fl.weather_trento_1" as (select "{'name': 'date', 'type': 'timestamp'}"...
#                                                   ^
# . gRPC client debug context: UNKNOWN:Error received from peer ipv4:51.79.26.27:5005 {grpc_message:"Binder Error: Referenced column \"{\'name\': \'date\', \'type\': \'timestamp\'}\" not found in FROM clause!\nCandidate bindings: \"read_parquet.date\"\nLINE 1: ...dictor_fl.weather_trento_1\" as (select \"{\'name\': \'date\', \'type\': \'timestamp\'}\"...\n                                                  ^. Detail: Python exception: Traceback (most recent call last):\n  File \"/usr/src/app/src/server.py\", line 142, in wrapper\n    result = func(*args, **kwargs)\n             ^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/src/app/src/server.py\", line 166, in wrapper\n    result = func(instance, *args, **kwargs)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/src/app/src/server.py\", line 196, in do_get\n    return self._read_query(context, path, command)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/src/app/src/server.py\", line 123, in wrapper\n    return func(instance, *args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/src/app/src/server.py\", line 131, in wrapper\n    result = func(*args, **kwargs)\n             ^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/src/app/src/server.py\", line 227, in _read_query\n    result_batches = self.hudi_query_engine.read_query(query_obj)\n                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/src/app/src/hudi_query_engine.py\", line 75, in read_query\n    with duckdb.connect(\n  File \"/usr/src/app/src/hudi_query_engine.py\", line 90, in read_query\n    self._register_featuregroups(\n  File \"/usr/src/app/src/hudi_query_engine.py\", line 112, in _register_featuregroups\n    self._register_hudi_featuregroups(hudi_featuregroups_paths, featuregroup_features, duckdb_con)\n  File \"/usr/src/app/src/hudi_query_engine.py\", line 126, in _register_hudi_featuregroups\n    duckdb_con.sql(query)\nduckdb.duckdb.BinderException: Binder Error: Referenced column \"{\'name\': \'date\', \'type\': \'timestamp\'}\" not found in FROM clause!\nCandidate bindings: \"read_parquet.date\"\nLINE 1: ...dictor_fl.weather_trento_1\" as (select \"{\'name\': \'date\', \'type\': \'timestamp\'}\"...\n                                                  ^\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"pyarrow/_flight.pyx\", line 2255, in pyarrow._flight._do_get\n  File \"/usr/src/app/src/server.py\", line 145, in wrapper\n    raise FlyingDuckException(str(e)) from e\nutils.exceptions.FlyingDuckException: Binder Error: Referenced column \"{\'name\': \'date\', \'type\': \'timestamp\'}\" not found in FROM clause!\nCandidate bindings: \"read_parquet.date\"\nLINE 1: ...dictor_fl.weather_trento_1\" as (select \"{\'name\': \'date\', \'type\': \'timestamp\'}\"...\n                                                  ^\n", grpc_status:2, created_time:"2026-01-05T18:33:42.182208+00:00"}. Client context: IOError: Server never sent a data message. Detail: Internal
# Error: Reading data from Hopsworks, using Hopsworks Feature Query Service
# ---------------------------------------------------------------------------
# FlightServerError                         Traceback (most recent call last)
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\hsfs\core\arrow_flight_client.py:418, in ArrowFlightClient._handle_afs_exception.<locals>.decorator.<locals>.afs_error_handler_wrapper(instance, *args, **kw)
#     417 try:
# --> 418     return func(instance, *args, **kw)
#     419 except Exception as e:
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\hsfs\core\arrow_flight_client.py:487, in ArrowFlightClient.read_query(self, query_object, arrow_flight_config, dataframe_type)
#     486 descriptor = pyarrow.flight.FlightDescriptor.for_command(query_encoded)
# --> 487 return self._get_dataset(
#     488     descriptor,
#     489     (
#     490         arrow_flight_config.get("timeout", self.timeout)
#     491         if arrow_flight_config
#     492         else self.timeout
#     493     ),
#     494     dataframe_type,
#     495 )
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\retrying.py:55, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      53 @wraps(f)
#      54 def wrapped_f(*args, **kw):
# ---> 55     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\retrying.py:279, in Retrying.call(self, fn, *args, **kwargs)
#     278 if not self.should_reject(attempt):
# --> 279     return attempt.get(self._wrap_exception)
#     281 self._logger.warning(attempt)
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\retrying.py:326, in Attempt.get(self, wrap_exception)
#     325         exc_type, exc, tb = self.value
# --> 326         raise exc.with_traceback(tb)
#     327 else:
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\retrying.py:273, in Retrying.call(self, fn, *args, **kwargs)
#     272 try:
# --> 273     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     274 except Exception:
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\hsfs\core\arrow_flight_client.py:473, in ArrowFlightClient._get_dataset(self, descriptor, timeout, dataframe_type)
#     470 options = pyarrow.flight.FlightCallOptions(
#     471     timeout=timeout, headers=self._certificates_headers()
#     472 )
# --> 473 reader = self._connection.do_get(info.endpoints[0].ticket, options)
#     474 _logger.debug("Dataset fetched. Converting to dataframe %s.", dataframe_type)
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\pyarrow\_flight.pyx:1745, in pyarrow._flight.FlightClient.do_get()
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\pyarrow\_flight.pyx:58, in pyarrow._flight.check_flight_status()
#
# FlightServerError: Binder Error: Referenced column "{'name': 'date', 'type': 'timestamp'}" not found in FROM clause!
# Candidate bindings: "read_parquet.date"
# LINE 1: ...dictor_fl.weather_trento_1" as (select "{'name': 'date', 'type': 'timestamp'}"...
#                                                   ^. Detail: Python exception: Traceback (most recent call last):
#   File "/usr/src/app/src/server.py", line 142, in wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/src/app/src/server.py", line 166, in wrapper
#     result = func(instance, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/src/app/src/server.py", line 196, in do_get
#     return self._read_query(context, path, command)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/src/app/src/server.py", line 123, in wrapper
#     return func(instance, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/src/app/src/server.py", line 131, in wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/src/app/src/server.py", line 227, in _read_query
#     result_batches = self.hudi_query_engine.read_query(query_obj)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/src/app/src/hudi_query_engine.py", line 75, in read_query
#     with duckdb.connect(
#   File "/usr/src/app/src/hudi_query_engine.py", line 90, in read_query
#     self._register_featuregroups(
#   File "/usr/src/app/src/hudi_query_engine.py", line 112, in _register_featuregroups
#     self._register_hudi_featuregroups(hudi_featuregroups_paths, featuregroup_features, duckdb_con)
#   File "/usr/src/app/src/hudi_query_engine.py", line 126, in _register_hudi_featuregroups
#     duckdb_con.sql(query)
# duckdb.duckdb.BinderException: Binder Error: Referenced column "{'name': 'date', 'type': 'timestamp'}" not found in FROM clause!
# Candidate bindings: "read_parquet.date"
# LINE 1: ...dictor_fl.weather_trento_1" as (select "{'name': 'date', 'type': 'timestamp'}"...
#                                                   ^
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "pyarrow/_flight.pyx", line 2255, in pyarrow._flight._do_get
#   File "/usr/src/app/src/server.py", line 145, in wrapper
#     raise FlyingDuckException(str(e)) from e
# utils.exceptions.FlyingDuckException: Binder Error: Referenced column "{'name': 'date', 'type': 'timestamp'}" not found in FROM clause!
# Candidate bindings: "read_parquet.date"
# LINE 1: ...dictor_fl.weather_trento_1" as (select "{'name': 'date', 'type': 'timestamp'}"...
#                                                   ^
# . gRPC client debug context: UNKNOWN:Error received from peer ipv4:51.79.26.27:5005 {grpc_message:"Binder Error: Referenced column \"{\'name\': \'date\', \'type\': \'timestamp\'}\" not found in FROM clause!\nCandidate bindings: \"read_parquet.date\"\nLINE 1: ...dictor_fl.weather_trento_1\" as (select \"{\'name\': \'date\', \'type\': \'timestamp\'}\"...\n                                                  ^. Detail: Python exception: Traceback (most recent call last):\n  File \"/usr/src/app/src/server.py\", line 142, in wrapper\n    result = func(*args, **kwargs)\n             ^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/src/app/src/server.py\", line 166, in wrapper\n    result = func(instance, *args, **kwargs)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/src/app/src/server.py\", line 196, in do_get\n    return self._read_query(context, path, command)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/src/app/src/server.py\", line 123, in wrapper\n    return func(instance, *args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/src/app/src/server.py\", line 131, in wrapper\n    result = func(*args, **kwargs)\n             ^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/src/app/src/server.py\", line 227, in _read_query\n    result_batches = self.hudi_query_engine.read_query(query_obj)\n                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/src/app/src/hudi_query_engine.py\", line 75, in read_query\n    with duckdb.connect(\n  File \"/usr/src/app/src/hudi_query_engine.py\", line 90, in read_query\n    self._register_featuregroups(\n  File \"/usr/src/app/src/hudi_query_engine.py\", line 112, in _register_featuregroups\n    self._register_hudi_featuregroups(hudi_featuregroups_paths, featuregroup_features, duckdb_con)\n  File \"/usr/src/app/src/hudi_query_engine.py\", line 126, in _register_hudi_featuregroups\n    duckdb_con.sql(query)\nduckdb.duckdb.BinderException: Binder Error: Referenced column \"{\'name\': \'date\', \'type\': \'timestamp\'}\" not found in FROM clause!\nCandidate bindings: \"read_parquet.date\"\nLINE 1: ...dictor_fl.weather_trento_1\" as (select \"{\'name\': \'date\', \'type\': \'timestamp\'}\"...\n                                                  ^\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"pyarrow/_flight.pyx\", line 2255, in pyarrow._flight._do_get\n  File \"/usr/src/app/src/server.py\", line 145, in wrapper\n    raise FlyingDuckException(str(e)) from e\nutils.exceptions.FlyingDuckException: Binder Error: Referenced column \"{\'name\': \'date\', \'type\': \'timestamp\'}\" not found in FROM clause!\nCandidate bindings: \"read_parquet.date\"\nLINE 1: ...dictor_fl.weather_trento_1\" as (select \"{\'name\': \'date\', \'type\': \'timestamp\'}\"...\n                                                  ^\n", grpc_status:2, created_time:"2026-01-05T18:33:42.182208+00:00"}. Client context: IOError: Server never sent a data message. Detail: Internal
#
# The above exception was the direct cause of the following exception:
#
# FeatureStoreException                     Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 X_train, X_test, y_train, y_test = feature_view.train_test_split(
#       2     test_start=test_start
#       3 )
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\hopsworks_common\usage.py:246, in method_logger.<locals>.wrapper(*args, **kwargs)
#     244 except Exception as e:
#     245     exception = e
# --> 246     raise e
#     247 finally:
#     248     try:
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\hopsworks_common\usage.py:242, in method_logger.<locals>.wrapper(*args, **kwargs)
#     239 exception = None
#     240 try:
#     241     # Call the original method
# --> 242     result = func(*args, **kwargs)
#     243     return result
#     244 except Exception as e:
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\hsfs\feature_view.py:2610, in FeatureView.train_test_split(self, test_size, train_start, train_end, test_start, test_end, description, extra_filter, statistics_config, read_options, spine, primary_key, event_time, training_helper_columns, dataframe_type, transformation_context, **kwargs)
#    2588 self._validate_train_test_split(
#    2589     test_size=test_size, train_end=train_end, test_start=test_start
#    2590 )
#    2591 td = training_dataset.TrainingDataset(
#    2592     name=self.name,
#    2593     version=None,
#    (...)
#    2608     extra_filter=extra_filter,
#    2609 )
# -> 2610 td, df = self._feature_view_engine.get_training_data(
#    2611     self,
#    2612     read_options,
#    2613     training_dataset_obj=td,
#    2614     splits=[TrainingDatasetSplit.TRAIN, TrainingDatasetSplit.TEST],
#    2615     spine=spine,
#    2616     primary_keys=kwargs.get("primary_keys") or primary_key,
#    2617     event_time=event_time,
#    2618     training_helper_columns=training_helper_columns,
#    2619     dataframe_type=dataframe_type,
#    2620     transformation_context=transformation_context,
#    2621 )
#    2622 warnings.warn(
#    2623     "Incremented version to `{}`.".format(td.version),
#    2624     util.VersionWarning,
#    2625     stacklevel=1,
#    2626 )
#    2627 self.update_last_accessed_training_dataset(td.version)
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\hsfs\core\feature_view_engine.py:501, in FeatureViewEngine.get_training_data(self, feature_view_obj, read_options, splits, training_dataset_obj, training_dataset_version, spine, primary_keys, event_time, training_helper_columns, dataframe_type, transformation_context)
#     488     self._check_feature_group_accessibility(feature_view_obj)
#     489     query = self.get_batch_query(
#     490         feature_view_obj,
#     491         training_dataset_version=td_updated.version,
#    (...)
#     499         spine=spine,
#     500     )
# --> 501     split_df = engine.get_instance().get_training_data(
#     502         td_updated,
#     503         feature_view_obj,
#     504         query,
#     505         read_options,
#     506         dataframe_type,
#     507         training_dataset_version,
#     508         transformation_context=transformation_context,
#     509     )
#     510     self.compute_training_dataset_statistics(
#     511         feature_view_obj, td_updated, split_df
#     512     )
#     514 # Getting transformed label names
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\hsfs\engine\python.py:1174, in Engine.get_training_data(self, training_dataset_obj, feature_view_obj, query_obj, read_options, dataframe_type, training_dataset_version, transformation_context)
#    1171     dataframe_type = "default"
#    1173 if training_dataset_obj.splits:
# -> 1174     return self._prepare_transform_split_df(
#    1175         query_obj,
#    1176         training_dataset_obj,
#    1177         feature_view_obj,
#    1178         read_options,
#    1179         dataframe_type,
#    1180         training_dataset_version,
#    1181         transformation_context=transformation_context,
#    1182     )
#    1183 else:
#    1184     df = query_obj.read(
#    1185         read_options=read_options, dataframe_type=dataframe_type
#    1186     )
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\hsfs\engine\python.py:1294, in Engine._prepare_transform_split_df(self, query_obj, training_dataset_obj, feature_view_obj, read_option, dataframe_type, training_dataset_version, transformation_context)
#    1287     else:
#    1288         # Use the fully qualified name of the event time feature if required
#    1289         event_time = event_time_feature[0]._get_fully_qualified_feature_name(
#    1290             feature_group=query_obj._left_feature_group
#    1291         )
#    1293         result_dfs = self._time_series_split(
# -> 1294             query_obj.read(
#    1295                 read_options=read_option, dataframe_type=dataframe_type
#    1296             ),
#    1297             training_dataset_obj,
#    1298             event_time,
#    1299         )
#    1300 else:
#    1301     result_dfs = self._random_split(
#    1302         query_obj.read(read_options=read_option, dataframe_type=dataframe_type),
#    1303         training_dataset_obj,
#    1304     )
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\hsfs\constructor\query.py:314, in Query.read(self, online, dataframe_type, read_options)
#     309     if len(self.joins) > 0 or None in [f.type for f in schema]:
#     310         raise ValueError(
#     311             "Pandas types casting only supported for feature_group.read()/query.select_all()"
#     312         )
# --> 314 return engine.get_instance().sql(
#     315     sql_query,
#     316     self._feature_store_name,
#     317     online_conn,
#     318     dataframe_type,
#     319     read_options,
#     320     schema,
#     321 )
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\hsfs\engine\python.py:152, in Engine.sql(self, sql_query, feature_store, online_conn, dataframe_type, read_options, schema)
#     142 def sql(
#     143     self,
#     144     sql_query: str,
#    (...)
#     149     schema: Optional[List[feature.Feature]] = None,
#     150 ) -> Union[pd.DataFrame, pl.DataFrame]:
#     151     if not online_conn:
# --> 152         return self._sql_offline(
#     153             sql_query,
#     154             dataframe_type,
#     155             schema,
#     156             arrow_flight_config=read_options.get("arrow_flight_config", {})
#     157             if read_options
#     158             else {},
#     159         )
#     160     else:
#     161         return self._jdbc(
#     162             sql_query, online_conn, dataframe_type, read_options, schema
#     163         )
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\hsfs\engine\python.py:295, in Engine._sql_offline(self, sql_query, dataframe_type, schema, arrow_flight_config)
#     292 if isinstance(sql_query, dict) and "query_string" in sql_query:
#     293     from hsfs.core import arrow_flight_client
# --> 295     result_df = util.run_with_loading_animation(
#     296         "Reading data from Hopsworks, using Hopsworks Feature Query Service",
#     297         arrow_flight_client.get_instance().read_query,
#     298         sql_query,
#     299         arrow_flight_config or {},
#     300         dataframe_type,
#     301     )
#     302 else:
#     303     raise ValueError(
#     304         "Reading data with Hive is not supported when using hopsworks client version >= 4.0"
#     305     )
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\hopsworks_common\util.py:377, in run_with_loading_animation(message, func, *args, **kwargs)
#     374 end = None
#     376 try:
# --> 377     result = func(*args, **kwargs)
#     378     end = time.time()
#     379     return result
#
# File c:\Users\nives\AllFolders\SML\sml-bike-sharing\.venv\lib\site-packages\hsfs\core\arrow_flight_client.py:440, in ArrowFlightClient._handle_afs_exception.<locals>.decorator.<locals>.afs_error_handler_wrapper(instance, *args, **kw)
#     438     raise FeatureStoreException(str(e).split("Details:")[0]) from e
#     439 else:
# --> 440     raise FeatureStoreException(user_message) from e
#
# FeatureStoreException: Could not read data using Hopsworks Query Service.
